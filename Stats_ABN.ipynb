# %% [markdown]
# <a href="https://colab.research.google.com/github/Keshav-Aggarwal/100DaysOfML/blob/master/Stats_ABN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ganesh-prabakaran/DriveBehaviorDataSet/master/data_sheet.csv')

# %%
df.head()
# Out:
#      USerID                 TripID   Start Date Time     End Date Time  \
# 0  UA000010  UA0000101515944903637  01/14/2018 15:48  01/14/2018 18:18
# 1  UA000020  UA0000201526044733754  05/11/2018 13:18  05/11/2018 14:30
# 2  UA000011  UA0000111543753379105  12/02/2018 12:22  12/02/2018 15:10
# 3  UA000020  UA0000201548952959262  01/31/2019 16:42  01/31/2019 20:12
# 4  UA000016  UA0000161534985084258  08/23/2018 00:44  08/23/2018 03:14
#
#    Trip Duration  Trip Run Time  Average \nSpeed\n(Km/h)  \
# 0            2.5            1.9                     87.6
# 1            1.2            0.9                     98.4
# 2            2.8            1.9                    106.8
# 3            3.5            2.5                     80.4
# 4            2.5            1.9                     94.8
#
#    Distance Covered\n(Km)  Traffic Signal Violations\n  \
# 0                   166.5                            0
# 1                    88.6                            3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998 entries, 0 to 1997
# Data columns (total 12 columns):
# USerID                                      1998 non-null object
# TripID                                      1998 non-null object
# Start Date Time                             1998 non-null object
# End Date Time                               1998 non-null object
# Trip Duration                               1998 non-null float64
# Trip Run Time                               1998 non-null float64
# Average
# Speed
# (Km/h)                       1998 non-null float64
# Distance Covered
# (Km)                       1998 non-null float64
# Traffic Signal Violations
#                   1998 non-null int64
# Speed Violations
# (in hours)                 1998 non-null float64
# Keep Safe distance violations
# (in hours)    1998 non-null float64
# Frequent lane change events
# (count)         1998 non-null int64
# dtypes: float64(6), int64(2), object(4)
# ...

# %%
df.describe()
# Out:
#        Trip Duration  Trip Run Time  Average \nSpeed\n(Km/h)  \
# count    1998.000000    1998.000000              1998.000000
# mean        2.076577       1.607257                90.157958
# std         1.153381       0.892983                10.576672
# min         0.100000       0.100000                72.000000
# 25%         1.100000       0.900000                81.600000
# 50%         2.100000       1.600000                90.000000
# 75%         3.100000       2.400000                99.600000
# max         4.000000       3.600000               108.000000
#
#        Distance Covered\n(Km)  Traffic Signal Violations\n  \
# count             1998.000000                  1998.000000
# mean               144.548148                     2.023524
# std                 82.092308                     1.230943
# min                  7.500000                     0.000000
# 25%                 77.050000                     1.000000
# ...

# %%
sns.pairplot(df)
